# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

def similarity_transformation(img):
    rows, cols = img.shape[:2]
    M = cv2.getRotationMatrix2D((cols/2,rows/2), 45, 1)
    result = cv2.warpAffine(img, M, (cols, rows))
    cv2_imshow( result)

def affine_transformation(img):
    rows, cols = img.shape[:2]
    pts1 = np.float32([[50,50],[200,50],[50,200]])
    pts2 = np.float32([[10,100],[200,50],[100,250]])
    M = cv2.getAffineTransform(pts1,pts2)
    result = cv2.warpAffine(img, M, (cols, rows))
    cv2_imshow( result)

def projective_transformation(img):
    rows, cols = img.shape[:2]
    pts1 = np.float32([[56,65],[368,52],[28,387],[389,390]])
    pts2 = np.float32([[0,0],[300,0],[0,300],[300,300]])
    M = cv2.getPerspectiveTransform(pts1,pts2)
    result = cv2.warpPerspective(img, M, (cols, rows))
    cv2_imshow(result)

def main():
    img = cv2.imread('/content/sample_data/sampleimg.png')
    print("Menu:\n1. Similarity Transformation\n2. Affine Transformation\n3. Projective Transformation\n4. Exit\n")
    choice = int(input("Enter your choice: "))
    while choice != 4:
        if choice == 1:
            similarity_transformation(img)
        elif choice == 2:
            affine_transformation(img)
        elif choice == 3:
            projective_transformation(img)
        else:
            print("Invalid choice. Please try again.")
        choice = int(input("Enter your choice: "))
    cv2.destroyAllWindows()

if __name__ == '__main__':
    main()
# Out:
# Menu:
# 1. Similarity Transformation
# 2. Affine Transformation
# 3. Projective Transformation
# 4. Exit
#
# Enter your choice: 3
# <PIL.Image.Image image mode=RGB size=558x633 at 0x7FE872CA1460>
